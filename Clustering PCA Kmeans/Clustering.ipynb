# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from Problem1 import k_means_pp, compute_objective, assign_data2clusters

# %%
iris = load_iris()
X_raw = iris.data
y = iris.target

# %%
x1 = X_raw[:, 0] / X_raw[:, 1]
x2 = X_raw[:, 2] / X_raw[:, 3]
X = np.column_stack((x1, x2))

plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolor='k')
plt.xlabel("x1")
plt.ylabel("x2")
plt.title("Features of Iris Dataset")
plt.colorbar()
plt.show()

# %%
objs = []

for k in range(1, 6):
    totalObj = 0
    for j in range(50):
        centers, d = k_means_pp(X, k, max_iter=100)
        totalObj += compute_objective(X, centers)
    averageObj = totalObj / 50
    objs.append(averageObj)

plt.figure(figsize=(8, 6))
plt.plot(ks, objs, marker='o')
plt.xlabel("k = ?")
plt.ylabel("Average Objective")
plt.title("Average Objective vs. k")
plt.show()

# %%
d, objVal = k_means_pp(X, 3, max_iter=50)


plt.figure()
plt.plot(objVal)
plt.xlabel("Iteration")
plt.ylabel("Objective")
plt.title("Objective for Iterations")
plt.show()

# %%
vals = assign_data2clusters(X, centers)
labels = np.argmax(vals, axis=1)
plt.figure()
plt.scatter(X[:, 0], X[:, 1], c=labels, edgecolor='k')
plt.scatter(centers[:, 0], centers[:, 1], c='pink', marker='x', label='Center', s=20)
plt.xlabel("x1")
plt.ylabel("x2")
plt.title("Center of Clusters")
plt.legend()
plt.show()
